# %% [markdown]
# # Simple loop agent
#
# In this example, we will create an loop agent that simply generate a description base on a same query and get all results
#
# In other word, this is a "for loop" agent.

# %%
from collections.abc import Sequence
from typing import List

from a2a.types import AgentCapabilities, AgentCard, AgentSkill
from aap_core.agent import BaseAgent
from aap_core.chain import BaseLLMChain
from aap_core.orchestration import LoopAgent
from aap_core.types import AgentMessage, AgentResponse
from aap_langchain.chain import ChatCausalMultiTurnsChain
from langchain_ollama import ChatOllama

# %%
class Agent(BaseAgent):
    chain: BaseLLMChain

    def execute(self, message: AgentMessage, **kwargs) -> AgentMessage:
        self.state = "running"
        message = self.chain.invoke(message, **kwargs)
        message.execution_result = "success"
        message.origin = self.card.name
        self.state = "idle"
        return message

# %%
from collections.abc import Generator

system_prompt = """You are a genius and creative writer.
"""

user_prompt = """{query}"""

max_iteration = 5

def state_callback(state: str):
    print(f"agent state: {state}")

def iter(max_iteration: int) -> Generator[bool, None, None]:
    n = 0
    while True:
        yield n >= max_iteration
        n = (n + 1) % (max_iteration + 1)

model = ChatOllama(model="llama3.2:latest", base_url="192.168.55.1:11434", temperature=1.5)
chain = ChatCausalMultiTurnsChain(model, system_prompt, user_prompt)
writer_skill = AgentSkill(
    id='writer-skill',
    name="writer skill",
    description="writer skill",
    tags=['writer']
)
writer_card = AgentCard(
    name="writer agent",
    description="Writer agent",
    skills=[writer_skill],
    capabilities=AgentCapabilities(),
    default_input_modes=['text'],
    default_output_modes=['text'],
    url="localhost",
    version="0.1.0"
)
loop_skill = AgentSkill(
    id='loop-skill',
    name="loop skill",
    description="loop skill",
    tags=['loop']
)
loop_card = AgentCard(
    name="loop agent",
    description="loop agent",
    skills=[loop_skill],
    capabilities=AgentCapabilities(),
    default_input_modes=['text'],
    default_output_modes=['text'],
    url="localhost",
    version="0.1.0"
)
agent = Agent(chain=chain, card=writer_card, state_change_callback=state_callback)
loop_agent = LoopAgent(agent=agent, is_stop=iter(max_iteration), card=loop_card, state_change_callback=state_callback)

# %%
query = "Write a short poem with Shakespere's style about the peace before the storm."
message = loop_agent.execute(AgentMessage(query=query), keep_result=-1)

print(message)
print(f"message responses len: {len(message.responses)}")

for agent_name, response in message.responses:
    print(f"{agent_name}: {response}")
    print("-" * 50)
    print()
# Out:
# agent state: loop agent:running/writer agent:idle
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#0/writer agent:running
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#1/writer agent:running
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#2/writer agent:running
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#3/writer agent:running
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:running#4/writer agent:running
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:idle/writer agent:idle
# query="Write a short poem with Shakespere's style about the peace before the storm." query_media=None query_media_type=None origin='loop agent' responses=[('writer agent', "O, fairest calm, that doth thy vigil keep,\nAs thunder gathers in the distant deep,\nThy peaceful hush, like whispered secrets sweet,\nDoth lull the world to slumber at our feet.\n\nThe wind, a gentle zephyr, soft and low,\nDoth blow a sigh of serenity, as snow\nFalls slow and silky from the heav'nly throne,\nIn whispered tones, that all hearts do know.\n\nBut oh, how fleeting is this tranquil nest,\nAs turmoil stirs, like sleeping giants pressed.\nThe calm gives way to tempest's savage roar,\nAnd darkness gathers at the stormy door.\n\nYet in thy gentle vigil, mortal soul\nDoth learn to cherish quiet, ere the gale be whole."), ('writer agent', "O, fairest calm, that doth thy reign unfold,\nA soothing balm, that calms the troubled mind.\n'Tis twilight's hush, when dawn and night are told,\nAnd nature's slumber, doth the heart entwine.\n\nThe winds do whisper
# As turmoil stirs, like sleeping giants pressed.
# The calm gives way to tempest's savage roar,
# And darkness gathers at the stormy door.
#
# Yet in thy gentle vigil, mortal soul
# Doth learn to cherish quiet, ere the gale be whole.
# --------------------------------------------------
#
# writer agent: O, fairest calm, that doth thy reign unfold,
# A soothing balm, that calms the troubled mind.
# 'Tis twilight's hush, when dawn and night are told,
# And nature's slumber, doth the heart entwine.
#
# The winds do whisper secrets in mine ear,
# Of tempests to come, of strife and woe's lair.
# But now, they cease, their moaning voice held dear,
# As if the skies themselves, did peaceful sleep declare.
#
# Yet, hidden beneath this tranquil face,
# A brewing turmoil, does a wicked race.
# Like embers smoldering, hot with rage and spite,
# Awaiting moment's spark, to unleash their fiery light.
#
# Oh, let us heed not the signs we yet miss here,
# Lest as the tempest rages, our own fate appear.
# But in this brief respite, from wrath's dark sway,
# May wisdom speak its truth, to drive the storms away.
# --------------------------------------------------
#
# writer agent: O, fair dawn's early break, when clouds do lie
# In tranquil folds, as soft as summer's sigh,
# And Nature's beauty, unencumbered stands,
# Unwrought by tempests, 'neath serene commands.
#
# The dewy morn, like gentle lover's kiss,
# Awakens hope and promise of the bliss,
# That comes before the raging storm doth break,
# And in the calm, all worldlies passions shake.
#
# Yet, in this peaceful hush, where worries fade,
# A secret turmoil brews beneath the shade,
# As winds, unseen by mortal eyes, prepare
# To bring the tempest forth, with thunderous glare.
#
# O, fleeting stillness, how thou dost deceive,
# Lest mortal men, like leafy branches leave,
# And in thy grasp, unheeding bliss do sleep,
# Till darkness gathers, and the storm doth creep.
# --------------------------------------------------
#
# writer agent: O, fairest calm, thy silence doth prevail,
# A lullaby of stillness, soft and frail.
# The winds, they whisper secrets in mine ear,
# Of tempests brewing, yet unseated fear.
#
# Thy gentle touch, a soothing balm to me,
# Doth lull the soul into a tranquil sea.
# But soft, what light through yonder darkness breaks?
# A glimmer of the fury that the storm doth make.
#
# The clouds, they gather, heavy with disdain,
# Their faces stern, their hearts in darkening pain.
# Yet still thou dost thy vigil keep, a sentry true,
# Watching and waiting, till the storm shall break anew.
#
# O, peace, thou art a fleeting thing, 'tis true,
# A moment's respite from fate's relentless pursue.
# For when thy calm hath ruled the troubled mind,
# The stormy rage of passions left behind.
# --------------------------------------------------
#
# writer agent: O, fairest calm, that doth beset our sight,
# A fleeting hush, that whispers sweet delight,
# As if 'twere summer's gentle breath that blows,
# And night's dark shadows did but softly flow.
#
# The winds, like sleepy lovers, slowly sway,
# Their sighs and murmurs echoing through the day,
# The trees, in slumber, stand with limbs outstretched,
# Their leaves, like golden tresses, gently sketched.
#
# But soft! what darkness gathers on the west?
# A smoldering ember, that doth find its nest
# In clouds congealed, like wrath-tinged mist that clings,
# And whispers secrets, of a storm that brings
#
# Its fierce tempests, and its torrential roar,
# That shatters calm, and leaves naught but sorrow's score.
#
# Yet still, the peaceful hour doth hold its ground,
# A tranquil refuge, 'twixt the waves unbound.
# For in this hush, before the storm doth break,
# We find a beauty, that our souls do undertake.
# --------------------------------------------------

# %%
query = "Write a poem with Shakespere's style about the peace before the storm."
message = loop_agent.execute(AgentMessage(query=query), keep_result=1)

print(message)
print(f"message responses len: {len(message.responses)}")

for agent_name, response in message.responses:
    print(f"{agent_name}: {response}")
    print("-" * 50)
    print()
# Out:
# agent state: loop agent:running/writer agent:idle
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#0/writer agent:running
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#1/writer agent:running
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#2/writer agent:running
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#3/writer agent:running
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:running#4/writer agent:running
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:idle/writer agent:idle
# query="Write a poem with Shakespere's style about the peace before the storm." query_media=None query_media_type=None origin='loop agent' responses=[('writer agent', "O, fairest calm, thou dost beset my soul\nWith whispers soft, of quiet, dark control\nA hush that doth descend, like twilight's sway\nAnd in thy gentle touch, all troubles flee away\n\nThe wind, a sleeping giant, lies beneath,\nHis rumblings muffled, his fury stilled and deep\nThe clouds, a canvas, white as freshly laid snow\nTheir creases smooth, their peaks unbroken, yet to grow\n\nThe trees, like sentinels of peace, stand tall\nTheir limbs outstretched, in supplication, one and all\nAs if in prayer, they waited for the sign\nThat signals tumult, strife, and nature's wild design\n\nAnd thou, O darkness, dost descend from above,\nA veil that doth conceal, the passions' fervent love\nThou dost beset my heart with anxious care\nLest in thy depths, a tempest waits to share\n\nYet still, I bide thy calm, and patiently endure\nThe expectation of thy coming, inevitable sure\nFor though thou hid'st within thy breast,\nA fire that burns, a wrath that will not rest.\n\nBut for now, 'tis peaceful night\nWhen darkness holds its vigil, in sweet delight\nI'll cherish this stillness, ere the storm breaks through\nAnd brings with it, the whirlwind's chaos anew.")] context=None execution_result=None error_message=None media=None media_type=None
# message responses len: 1
# writer agent: O, fairest calm, thou dost beset my soul
# With whispers soft, of quiet, dark control
# A hush that doth descend, like twilight's sway
# And in thy gentle touch, all troubles flee away
#
# The wind, a sleeping giant, lies beneath,
# His rumblings muffled, his fury stilled and deep
# The clouds, a canvas, white as freshly laid snow
# Their creases smooth, their peaks unbroken, yet to grow
#
# The trees, like sentinels of peace, stand tall
# Their limbs outstretched, in supplication, one and all
# As if in prayer, they waited for the sign
# That signals tumult, strife, and nature's wild design
#
# And thou, O darkness, dost descend from above,
# A veil that doth conceal, the passions' fervent love
# Thou dost beset my heart with anxious care
# Lest in thy depths, a tempest waits to share
#
# Yet still, I bide thy calm, and patiently endure
# The expectation of thy coming, inevitable sure
# For though thou hid'st within thy breast,
# A fire that burns, a wrath that will not rest.
#
# But for now, 'tis peaceful night
# When darkness holds its vigil, in sweet delight
# I'll cherish this stillness, ere the storm breaks through
# And brings with it, the whirlwind's chaos anew.
# --------------------------------------------------

# %%
query = "Write a poem with Shakespere's style about the peace before the storm."
message = loop_agent.execute(AgentMessage(query=query), keep_result=3)

print(message)
print(f"message responses len: {len(message.responses)}")

for agent_name, response in message.responses:
    print(f"{agent_name}: {response}")
    print("-" * 50)
    print()
# Out:
# agent state: loop agent:running/writer agent:idle
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#0/writer agent:running
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#1/writer agent:running
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#2/writer agent:running
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#3/writer agent:running
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:running#4/writer agent:running
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:idle/writer agent:idle
# query="Write a poem with Shakespere's style about the peace before the storm." query_media=None query_media_type=None origin='loop agent' responses=[('writer agent', "O, fairest eve, when sun doth set so low,\nAnd darkness gathers, like a cloak to throw,\nA sense of calm doth reign, a stillness deep,\nAs if the world, in slumber, doth softly creep.\n\nThe winds, they whisper secrets in my ear,\nOf tempests yet to come, and fears to fear,\nYet, in this hush, I find a strange delight,\nA peaceful respite, from chaos' raging light.\n\nThe stars, like diamonds, twinkle bright above,\nAs if to bid the night, with gentle love,\nThe world, it seems, hath ceased its troubled pace,\nAnd for a moment, time doth stand in quiet space.\n\nBut then, a rustling sound, a distant sigh,\nDoth pierce the stillness, like a sorr
# Of tempests yet to come, and fears to fear,
# Yet, in this hush, I find a strange delight,
# A peaceful respite, from chaos' raging light.
#
# The stars, like diamonds, twinkle bright above,
# As if to bid the night, with gentle love,
# The world, it seems, hath ceased its troubled pace,
# And for a moment, time doth stand in quiet space.
#
# But then, a rustling sound, a distant sigh,
# Doth pierce the stillness, like a sorrow's cry,
# A warning whispered, of impending doom's might,
# As darkness gathers, and the tempest takes flight.
#
# Yet still, I bask, in this eerie, golden glow,
# A fleeting peace, that beckons me to know
# The truth behind the veil, that hides from sight,
# And in its heart, a stormy passion doth take flight.
#
# For though it tempts, with visions of release,
# This calm, sweet moment, is but a precursor's plea,
# To those who sense the gathering tempests' roar,
# A signal that the storm, that awaits us more.
# --------------------------------------------------
#
# writer agent: O, fairest eve, that doth presage the night
# Of tempests' fury, darkness, and despair,
# A fleeting calm, that doth my senses light,
# As in thy peaceful slumber, I prepare.
#
# The wind doth whisper secrets in mine ear,
# Of turmoil brewing, 'neath the sun's warm ray;
# Yet, in thine eye, a gentle gleam doth appear,
# That calms my heart, and whispers "all is well" by day.
#
# Thy waves, they lap at the still shore,
# As if to warn me of the storms yet to be,
# And yet, their soothing melody doth play
# Upon mine ears, in sweet, sweet symphony.
#
# Oh, fleeting peace, how soon thou art forgot,
# When fierce gusts blow thee away, like autumn's withered thread;
# But now, as sunbeams dance upon thy waves so bright,
# I'll cherish thee, fair eve, my tranquil refuge and delight.
#
# Yet, I do know the moods of Nature's queen,
# Who weeps, when storms arise, her silent, angry sheen;
# So let me not be fooled by thine serene facade,
# For in the depths of thee, a stormy tempest waits its shade.
#
# Farewell, dear peace, that brief and shining spell,
# May thy calm soothe my soul, as final darkness falls to dwell.
# I'll take one last look at thee, before the night doth descend
# And sweep away our whispers, with a blast of fiery wind.
# --------------------------------------------------
#
# writer agent: O, fairest eve, that doth precede the night
# When tempests gather, like dark thoughts in sight,
# A sense of calm, a peaceful silence lies
# Upon thy gentle breast, a soothing surprise.
#
# As sunbeams fade and light's warm rays grow cold,
# Thy warmth doth dwindle, and thy stars unfold,
# Like secrets whispered 'twixt the twilight's ear,
# And darkness trembles at their coming near.
#
# The winds, that once did whispers promise sweet,
# Now whisper low of trouble to meet,
# Their sighs and moans, a murmur of dismay
# As shadows stir, like waking thoughts astray.
#
# Yet still thou standest, steadfast as the night,
# A sentinel 'twixt peace and stormy fight,
# A shield 'gainst wrath, a sanctuary fair,
# Where troubled souls may find their anxious care.
#
# Thy tranquil heart, a balm to soothing pain,
# Doth quiet tumult, like a summer's rain
# That brings relief from fiery summer's blaze,
# And with its coolness calms the tempest's ways.
#
# O fairest eve, that doth foretell the strife,
# Take heed! thy peaceful slumber be but brief
# For in the morning's dawn, the storm's dark form
# Shall rise, like Phoebus, to thy troubled storm.
#
# Then, while thou canst, enjoy this tranquil reign,
# For in its depths, thou shalt find strength to sustain
# Thy courage through life's trials, and darkest night
# And emerge, a phoenix, from thy burning light.
# --------------------------------------------------

# %%
def custom_keep_logic(responses: Sequence[AgentResponse]) -> List[AgentResponse]:
    return list(responses)


query = "Write a poem with Shakespere's style about the peace before the storm."
message = loop_agent.execute(AgentMessage(query=query), keep_result
, thy deceptive smile doth lure,\nAnd beckon me to pause and gaze awhile,\nFor \'tis in peace that danger oft doth hide,\nAnd tempests rage, with violence unbridled and wide.\n\nYet, I am fooled by beauty\'s subtle snare,\nThat lures my footsteps forth, without a care,\nInto the breach of safety\'s false appearance deep,\nWhere chaos gathers strength to unleash its keep.\n\nAlas, wise eyes see beyond thy guile,\nFor storms gather swift, like furious passions\' smile,\nAnd in their fury, I am made to wend\nMy way through tempests, and tumult\'s discordant end.'), ('writer agent', "O, fairest calm of skies, thou dost ascend\nIn tranquil majesty, as sunset doth descend\nUpon thy stage, where clouds congregate in deep,\nAnd thunder whispers secrets, y ...
# message responses len: 5
# writer agent: O, fairest eve, thy gentle hue doth shine
# As if 'twere painted by the sun itself divine,
# Yet in thy soft and whispered breath, I find
# A portent of the turmoil to come.
#
# The wind doth softly sigh, a gentle hush
# That whispers secrets of the tempest's rush,
# And though the stars above their watchful gaze
# Do not disturb the quiet evening's ways,
#
# My heart doth stir with dread, my senses keen
# As if they felt the gathering storm unseen.
# For in thy peaceful stillness, I do sense
# The thrumming drums of fate, the deadly dance.
#
# O, woe betide me, who in wisdom's guise
# Do read the signs of Nature's troubled eyes,
# That now the calm and darkness softly veil
# A whirlwind's fury, swift and merciless to fail.
#
# Yet even as the darkness gathers fast
# And storms within my heart do loudly blast,
# I find a fleeting peace, a stillness true
# That stands 'twixt life and death, a moment's clue
#
# To live for now, and let the tempest rage,
# For in its roar, I hear the wisdom of the age:
# That though the storm will pass, the calm shall follow fast,
# And in the stillness, beauty forever shall be cast.
#
# But oh, when darkness closes round my sight
# And the wind howls loud with wrathful cry and night,
# I'll hold this moment to my heart and mind
# The fleeting peace before the storm's wild din.
# --------------------------------------------------
#
# writer agent: O, fair tranquility, thou art a gentle breeze
# That whispers secrets in mine eager ears,
# A soft susurrus that doth lull me to ease,
# And calm the troubled waters of my fears.
#
# Thy stillness spreads, like dawn's roseate hue
# Across the sky, and darkness fades from sight,
# As if the very winds themselves were anew,
# And in thy presence, I take gentle flight.
#
# But lo, fair peace, how oft thou art but born
# Of turmoil's reign, when darkness gathereth near,
# And on the morrow, stormy tempests scorn
# Thy sweet serenity, and all that is sincere.
#
# Yet still, fair tranquil maid, thou dost entice
# My heart with gentle pleasures, like a lover's sigh,
# A respite from pain, a brief release of time,
# When darkness seems to hold its hold no more.
#
# O, fleeting calm! How soon thy wings do fade,
# And wilder winds arise, as tempests gather near,
# To shatter what was calm and peaceful laid
# Before the maelstrom's roaring voice is clear.
#
# But while thou art mine own, sweet tranquil bliss,
# I'll cling to thee, dear peace, with eager hands,
# For in thy quiet hours, my heart doth find
# A respite from turmoil's dark command.
# --------------------------------------------------
#
# writer agent: O, fairest calm, thou dost deceive mine eyes,
# A gentle breeze that doth caress the skies,
# And whispers soft, as if 'twere but a sigh,
# "Peace reigns, and danger passes thee by."
#
# The trees, they stand in stillness, void of sound,
# Their leaves rustling softly, like a lover's breath around,
# The wind doth whisper secrets, low and deep and old,
# As earthy scents ascend, and youthful greens unfold.
#
# The heavens, clear as crystal glass, now gaze
# Upon the world below, with gentle amaze,
# The clouds, they gather not in stormy grey,
# But hide behind a veil of misty disarray.
#
# O, fairest calm, thy deceptive smile doth lure,
# And beckon me to pause and gaze awhile,
# For 'tis in peace that danger oft doth hide,
# And tempests rage, with violence unbridled and wide.
#
# Yet, I am fooled by beauty's subtle snare,
# That lures my footsteps forth, without a care,
# Into the breach of safety's false appearance deep,
# Where chaos gathers strength to unleash its keep.
#
# Alas, wise eyes see beyond thy guile,
# For storms gather swift, like furious passions' smile,
# And in their fury, I am made to wend
# My way through tempests, and tumult's discordant end.
# --------------------------------------------------
#
# writer agent: O, fairest calm of skies, thou dost ascend
# In tranquil majesty, as sunset doth descend
# Upon thy stage, where clouds congregate in deep,
# And thunder whispers secrets, yet to be unseated.
#
# Thy silence speaks of peace, a gentle hush,
# That doth allay the fears that troubled whispers rush
# From frantic birds, who once with urgency did flit
# But now, in stilled repose, their vigil hold and hit
#
# The trees, like sentinels of solemn watch, stand tall
# Their leaves, a soft susurrus, as the wind doth pass 'twixt all
# No signs of tempests' turmoil here; no strife doth mar
# The beauty that now blooms, with promise of calm afar
#
# Yet, in this quiet, subtle signs are sown
# A whispered warning of the passions yet to be unleashed and grown
# A foreshadowing of great rage to come,
# A reckoning fierce, with consequences to succumb
#
# So let us bask in tranquil joyous delight
# Before the darkness breaks, and tumultous wrath doth take its right
# For though this storm may bring great turmoil's night
# Peace shall give way, like dawn, when darkest chaos takes flight.
# --------------------------------------------------
#
# writer agent: O, fairest eve, that doth descend to earth,
# With gentle whispers, soft as lover's birth,
# The wind doth sigh, and trembles with anticipation,
# As if the skies themselves did whisper secret instruction.
#
# The stars above, like diamonds in the night,
# Do twinkle, wink, and wink again with mischief bright,
# Their light, a harbinger of tumult to come,
# A promise of the tempest's mighty drum.
#
# Yet, in this fleeting calm, we find a peace
# That doth defy the darkness yet to seep,
# For in the stillness, we may find our strength,
# To weather life's great stormy length.
#
# The trees, like sentinels of nature's throne,
# Stand guard, their leaves a rustling, whispered tone,
# A gentle warning, lest we be unprepared,
# For tempests wild, that come with no regard.
#
# Oh, fairest eve, how swiftly thou dost fade,
# Leaving us exposed to wrath and fury made,
# But in this moment's pause, before the gale
# Doth break and rage, let wisdom hold us frail.
#
# Then take this hush of calm, this brief reprieve,
# And tempering hope with prudence, let us strive to breathe,
# For though the storm may come, as it is wont,
# In peace and calm we find our souls are bent.
#
# Note: I tried to emulate Shakespeare's style by using:
#
# * Iambic pentameter (5 feet per line)
# * Archaic vocabulary
# * Elizabethan English (dropping 's' at the end of words where modern English tends to pronounce it as a syllable)
# * Shakespearean metaphors (comparing evening sky with diamonds, etc.)
# * Sonnet-inspired structure
# --------------------------------------------------

# %% [markdown]
# # Cross reflection pattern
#
# This pattern principally similar to the self-reflection pattern, the only different point is reflection is performed by another agent.

# %%
from typing import List

from a2a.types import AgentCapabilities, AgentCard, AgentSkill
from aap_core.agent import AgentMessage
from aap_core.orchestration import ReflectionAgent
from aap_core.types import AgentResponse
from aap_dspy.chain import BaseSignatureAdapter, ChatCausalMultiTurnsChain

import dspy

# %%
model_task = dspy.LM(model="ollama_chat/qwen3:4b-thinking-2507-q4_K_M", api_base="http://192.168.55.1:11434", api_key="", cache=False, max_tokens=16384)
model_relfection = dspy.LM(model="ollama_chat/granite3.3:8b", api_base="http://192.168.55.1:11434", api_key="", cache=False, max_tokens=65536)

# %%
class QA(dspy.Signature):
    guide: str = dspy.InputField(optional=True)
    context: str = dspy.InputField(optional=True)
    question: str = dspy.InputField()
    answer: str = dspy.OutputField()
    history: dspy.History = dspy.InputField()


class SignatureAdapter(BaseSignatureAdapter[QA]):
    def msg2sig(self, message: AgentMessage) -> List[QA]:
        history = dspy.History(messages=[])
        q, a = None, None
        for response in message.responses:
            if response[0] == "user":
                q = response[1]
            elif response[0] == "tool":
                pass
            elif response[0] == "system":
                pass
            else:
                a = response[1]

            if q is not None and a is not None:
                history.messages.append({"question": q, "answer": a})
                q, a = None, None

        context_str = ""
        if message.context is not None:
            context_str = message.context.get("response", None)
        guide_str = self._prefill_dict.get("guide", "")
        qa = QA(question=message.query, answer="", history=history, guide=guide_str, context=context_str)
        return [qa]

    def sig2msg(self, signatures: List[QA], name: str) -> List[AgentResponse]:
        responses = []
        for signature in signatures:
            responses.append(("user", signature.question))
            responses.append((name, signature.answer))
        return responses

# %%
# Notice that with dspy, we don't have user prompt template, as the signature is doing the job already

predictor = dspy.ChainOfThought(QA)

system_prompt_task = """/no_think You are a helpful coding assistant.
You task is to write a python function and return the implementation of the function.
Some requirements:
- The logic is clear and easy to understand.
- The function arguments and return values (if any) should be typed.
- If the function is too long (for example greater than 80 lines), split the logic into multiple smaller functions.
- All functions should have docstring explanation. In the explanation, there should be an simple example to illustrate the function and how to call it.
- The response should contain function with docstring explanation. And DO NOT contain explanation outside of the code
"""
task_adapter = SignatureAdapter.with_prefill({"guide": system_prompt_task})
task_chain = ChatCausalMultiTurnsChain(QA, predictor=predictor, adapter=task_adapter).with_lm(model_task)
task_chain.final_response_as_context("response")

system_prompt_reflection = """/no_think You are a excellent code reviewer and refactor.
Given a function implementation and it explanation in the context field, your task is to review the code and correct if contains any mistake.
Some note:
- For the implementation, check if the orignal query and suggested implementation are match.
- Is there any syntax error in the code.
- For the explanation, verify if the docstring follows Google style docstring.
- In the docstring, make sure to have an example to call the function.
- Make sure the final output only contain code, inline code comment and docstring, nothing else.
- If no modificatoin is made, just return the original implementation"""
# Use different llm for cross-reflection
reflection_adapter = SignatureAdapter.with_prefill({"guide": system_prompt_reflection})
reflection_chain = ChatCausalMultiTurnsChain(QA, predictor=predictor, adapter=reflection_adapter).with_lm(model_relfection)

def state_callback(state: str):
    print(f"agent state: {state}")

reflection_skill = AgentSkill(
    id='reflection-skill',
    name="reflection skill",
    description="self-reflection skill",
    tags=['reflection']
)
reflection_card = AgentCard(
    name="reflection agent",
    description="self-reflection agent",
    skills=[reflection_skill],
    capabilities=AgentCapabilities(),
    default_input_modes=['text'],
    default_output_modes=['text'],
    url="localhost",
    version="0.1.0"
)

reflection_agent = ReflectionAgent(card=reflection_card, chain_task=task_chain, chain_reflection=reflection_chain, state_change_callback=state_callback)

# %%
# Take a leetcode as an example. Source: https://leetcode.com/problems/integer-to-roman/description/
query = """Seven different symbols represent Roman numerals with the following values:

Symbol	Value
I	1
V	5
X	10
L	50
C	100
D	500
M	1000
Roman numerals are formed by appending the conversions of decimal place values from highest to lowest. Converting a decimal place value into a Roman numeral has the following rules:

If the value does not start with 4 or 9, select the symbol of the maximal value that can be subtracted from the input, append that symbol to the result, subtract its value, and convert the remainder to a Roman numeral.
If the value starts with 4 or 9 use the subtractive form representing one symbol subtracted from the following symbol, for example, 4 is 1 (I) less than 5 (V): IV and 9 is 1 (I) less than 10 (X): IX. Only the following subtractive forms are used: 4 (IV), 9 (IX), 40 (XL), 90 (XC), 400 (CD) and 900 (CM).
Only powers of 10 (I, X, C, M) can be appended consecutively at most 3 times to represent multiples of 10. You cannot append 5 (V), 50 (L), or 500 (D) multiple times. If you need to append a symbol 4 times use the subtractive form.
Given an integer, convert it to a Roman numeral.

Example 1:
Input: num = 3749
Output: "MMMDCCXLIX"
Explanation:
3000 = MMM as 1000 (M) + 1000 (M) + 1000 (M)
 700 = DCC as 500 (D) + 100 (C) + 100 (C)
  40 = XL as 10 (X) less of 50 (L)
   9 = IX as 1 (I) less of 10 (X)
Note: 49 is not 1 (I) less of 50 (L) because the conversion is based on decimal places

Example 2:
Input: num = 58
Output: "LVIII"
Explanation:
50 = L
 8 = VIII"""

final_message = reflection_agent.execute(AgentMessage(query=query))
for response in final_message.responses:
    name, msg = response
    print("-" * 50)
    print(name)
    print(msg)
    print("-" * 50)
# Out:
# agent state: reflection agent:running
#
#
#
#
# [2025-12-10T10:50:24.609667]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `context` (str):
# 3. `question` (str):
# 4. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `context`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# /no_think You are a helpful coding assistant.
# You task is to write a python function and return the implementation of the function.
# Some requirements:
# - The logic is clear and easy to understand.
# - The function arguments and return values (if any) should be typed.
# - If the function is too long (for example greater than 80 lines), split the logic into multiple smaller functions.
# - All functions should have docstring explanation. In the explanation, there should be an simple example to illustrate the function and how to call it.
# - The response should contain function with docstring explanation. And DO NOT contain explanation outside of the code
#
#
# [[ ## context ## ]]
#
#
# [[ ## question ## ]]
# Seven different symbols represent Roman numerals with the following values:
#
# Symbol	Value
# I	1
# V	5
# X	10
# L	50
# C	100
# D	500
# M	1000
# Roman numerals are formed by appending the conversions of decimal place values from highest to lowest. Converting a decimal place value into a Roman numeral has the following rules:
#
# If the value does not start with 4 or 9, select the symbol of the maximal value that can be subtracted from the input, append that symbol to the result, subtract its value, and convert the remainder to a Roman numeral.
# If the value starts with 4 or 9 use the subtractive form representing one symbol subtracted from the following symbol, for example, 4 is 1 (I) less than 5 (V): IV and 9 is 1 (I) less than 10 (X): IX. Only the following subtractive forms are used: 4 (IV), 9 (IX), 40 (XL), 90 (XC), 400 (CD) and 900 (CM).
# Only powers of 10 (I, X, C, M) can be appended consecutively at most 3 times to represent multiples of 10. You cannot append 5 (V), 50 (L), or 500 (D) multiple times. If you need to append a symbol 4 times use the subtractive form.
# Given an integer, convert it to a Roman numeral.
#
# Example 1:
# Input: num = 3749
# Output: "MMMDCCXLIX"
# Explanation:
# 3000 = MMM as 1000 (M) + 1000 (M) + 1000 (M)
#  700 = DCC as 500 (D) + 100 (C) + 100 (C)
#   40 = XL as 10 (X) less of 50 (L)
#    9 = IX as 1 (I) less of 10 (X)
# Note: 49 is not 1 (I) less of 50 (L) because the conversion is based on decimal places
#
# Example 2:
# Input: num = 58
# Output: "LVIII"
# Explanation:
# 50 = L
#  8 = VIII
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# Okay, so I need to write a Python function that converts an integer to a Roman numeral. Let me think about how to approach this.
#
# First, the problem says there are seven symbols with specific values. The rules involve subtractive forms like IV for 4, IX for 9, etc. The key is to handle the subtractive cases and then build the Roman numeral from highest to lowest.
#
# I remember that Roman numerals are constructed by subtracting certain values when the next higher value is needed. For example, 4 is IV (5 - 1), 9 is IX (10 - 1), 40 is XL (50 - 10), etc.
#
# The standard approach for this problem is to have a list of tuples that map integer values to their corresponding Roman numeral strings, ordered from largest to smallest. Then, iterate through this list, subtracting the largest possible value from the number each time, and appending the corresponding symbol to the result.
#
# Wait, but the problem mentions that only certain subtractive forms are allowed. So the list should include the subtractive pairs as well. For example, for 400, it's CD (500 - 100), so the list should have entries like (1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'), etc.
#
# Let me list out the possible values in descending order. The standard values are:
#
# 1000: M
# 900: CM
# 500: D
# 400: CD
# 100: C
# 90: XC
# 50: L
# 40: XL
# 10: X
# 9: IX
# 5: V
# 4: IV
# 1: I
#
# So the order of the list should be from highest to lowest: 1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1.
#
# Wait, but the problem says that only certain subtractive forms are used, so the list should include the subtractive combinations as single entries. For example, 900 is represented as 'CM', so in the list, the entry for 900 is 'CM'.
#
# So the code would iterate through this list, and for each value, subtract it from the input number as many times as possible, appending the corresponding symbol.
#
# Wait, but the problem says that the function should return the Roman numeral as a string.
#
# Let me think: For example, if the input is 3749, the function should return "MMMDCCXLIX".
#
# So, the approach is:
#
# 1. Create a list of tuples where each tuple is (integer value, corresponding Roman numeral string), ordered from highest to lowest.
#
# 2. Initialize an empty string for the result.
#
# 3. For each value in the list:
#    a. While the current number is greater than or equal to the value:
#       i. Append the Roman numeral string to the result.
#       ii. Subtract the value from the number.
#
# Wait, but the problem states that the subtractive forms are only for 4 and 9 in the decimal places. So the list should be ordered such that the subtractive pairs are included as single entries. For example, 900 is 'CM', so when the number is 900, we add 'CM' once.
#
# So the list would be:
#
# [
#     (1000, 'M'),
#     (900, 'CM'),
#     (500, 'D'),
#     (400, 'CD'),
#     (100, 'C'),
#     (90, 'XC'),
#     (50, 'L'),
#     (40, 'XL'),
#     (10, 'X'),
#     (9, 'IX'),
#     (5, 'V'),
#     (4, 'IV'),
#     (1, 'I')
# ]
#
# Yes, this list covers all the possible cases. Now, the algorithm would be:
#
# For the given integer num, iterate through this list. For each value in the list:
#
# - While num >= value:
#    - Add the corresponding symbol to the result
#    - Subtract value from num
#
# This way, for example, 4 would be handled by the 'IV' entry, since 4 >= 4, so add 'IV' once, then num becomes 0.
#
# Let me test this with example 2: num = 58.
#
# The list starts with 1000, which is larger than 58, so skip. Then 900, 500, 400, 100, 90 (90 is larger than 58? No, 90 is 90, which is larger than 58. Wait, no: 90 is 90, so 58 is less than 90. So the next is 50: 50 is in the list. 58 >=50: add 'L', subtract 50, remaining 8.
#
# Then next is 40: 8 <40, skip. Then 10: 8 <10, skip. Then 9: 8 <9, skip. Then 5: 8 >=5: add 'V', subtract 5, remaining 3. Then 4: 3 <4, skip. Then 1: 3 >=1: add 'I' three times. So result is 'L' + 'V' + 'III' = 'LVIII' which is correct.
#
# Yes, this approach seems to work.
#
# So the function would be:
#
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# Wait, but the problem says that the function should have a docstring with an example. Let me check the example.
#
# In the example, for 58, the output is 'LVIII', which matches.
#
# Another test: num=3749.
#
# Let's see:
#
# 3749 divided by 1000: 3 times, so MMM (3000).
#
# 3749-3000 = 749.
#
# 749: next is 500 (D) → 749 >=500 → D, now 249.
#
# 249: next 100 (C) → 249 >=100 → C, 149.
#
# 149: next 100 → C, now 49.
#
# 49: 40 (XL) → 49 >=40 → XL, 9.
#
# 9: IX → I and X? Wait, 9 is 'IX', so append 'IX' once.
#
# So result is MMM + DCC (200) → DCC is 500 + 100 + 100 → 700? Wait, 3000 + 700 = 3700, then 40 and 9 → 49. So 3749 → MMM D CC XL IX → MMMDCCXLIX.
#
# Yes, which matches the example.
#
# So the code should work.
#
# The function is under 80 lines, so no need to split into smaller functions. The docstring has an example.
#
# Let me check the requirements again:
#
# - The logic is clear and easy to understand: yes, the code uses a list of tuples and iterates through them.
#
# - Arguments and return values typed: yes, num is int, returns str.
#
# - Not too long: this code is short.
#
# - Docstring with example: yes.
#
# So the answer should be this function.
#
# Wait, the problem says "DO NOT contain explanation outside of the code". So the response should only have the code with the docstring, no extra text.
#
# So the answer field should be the code block.
#
# Wait, the user's instruction says: "The response should contain function with docstring explanation. And DO NOT contain explanation outside of the code".
#
# So the answer is the code.
#
# So the output should be:
#
# [[ ## reasoning ## ]]
# The function uses a list of tuples (integer values and corresponding Roman symbols) ordered from highest to lowest. It iterates through this list, appending the symbol to the result each time the current number is greater than or equal to the value, then subtracts the value from the number. This handles subtractive cases like IV (4) and IX (9) by including them as single entries in the list. The algorithm ensures the correct conversion by processing the highest possible values first.
#
# [[ ## answer ## ]]
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# [[ ## completed ## ]]
#
# Wait, but the problem says that the function should be written with the docstring. The example uses a triple-slash comment, but in Python, the docstring is a triple quote.
#
# Wait, the code I wrote has a docstring starting with triple quotes. Wait, no: in the code above, the docstring is written with a triple quote. Let me check.
#
# In the code as written:
#
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [ ... ]
#
# Yes, the docstring uses triple quotes. Wait, no: in Python, the docstring starts with triple quotes. Wait, but in the code I wrote, it's using triple quotes.
#
# Wait, no: the user's example uses a triple-quoted string. Wait, the code I wrote has a docstring that's a triple-quoted string.
#
# Wait, no: in the code above, the docstring is written with triple quotes. Let me check.
#
# In Python, a docstring is written as:
#
# '''...'''
#
# But in the code I wrote, the docstring starts with a triple quote. Wait, no. The code I wrote has:
#
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#
# This is a multiline docstring without triple quotes. Wait, no: in Python, the standard way is to use triple quotes for multi-line docstrings. But in the code, the user's example shows that the docstring can be written with triple quotes.
#
# Wait, the problem says: "All functions should have docstring explanation. In the explanation, there should be an simple example to illustrate the function and how to call it."
#
# In the code, the docstring is written with triple quotes. Let me adjust the code to use triple quotes.
#
# Wait, in Python, the correct way to write a multi-line docstring is with triple quotes. So the code should be:
#
# def int_to_roman(num):
#     """
#     Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# Yes, this uses triple quotes for the docstring. So the code is correct.
#
# So the answer field should be this code.
#
# Let me check the example. The function returns 'LVIII' for 58, which matches.
#
# Yes. So the code should be correct.
#
# Therefore, the reasoning is as above, and the answer is the code.
# </think>
#
# [[ ## reasoning ## ]]
# The function uses a list of tuples (integer values and corresponding Roman symbols) ordered from highest to lowest. It iterates through this list, appending the symbol to the result each time the current number is greater than or equal to the value, then subtracts the value from the number. This handles subtractive cases like IV (4) and IX (9) by including them as single entries in the list. The algorithm ensures correct conversion by processing the highest possible values first.
#
# [[ ## answer ## ]]
# def int_to_roman(num):
#     """
#     Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# [[ ## completed ## ]]
#
#
#
#
#
# agent state: reflection agent:reflecting
#
#
#
#
# [2025-12-10T10:50:55.436357]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `context` (str):
# 3. `question` (str):
# 4. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `context`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# /no_think You are a excellent code reviewer and refactor.
# Given a function implementation and it explanation in the context field, your task is to review the code and correct if contains any mistake.
# Some note:
# - For the implementation, check if the orignal query and suggested implementation are match.
# - Is there any syntax error in the code.
# - For the explanation, verify if the docstring follows Google style docstring.
# - In the docstring, make sure to have an example to call the function.
# - Make sure the final output only contain code, inline code comment and docstring, nothing else.
# - If no modificatoin is made, just return the original implementation
#
# [[ ## context ## ]]
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# [[ ## question ## ]]
# Seven different symbols represent Roman numerals with the following values:
#
# Symbol	Value
# I	1
# V	5
# X	10
# L	50
# C	100
# D	500
# M	1000
# Roman numerals are formed by appending the conversions of decimal place values from highest to lowest. Converting a decimal place value into a Roman numeral has the following rules:
#
# If the value does not start with 4 or 9, select the symbol of the maximal value that can be subtracted from the input, append that symbol to the result, subtract its value, and convert the remainder to a Roman numeral.
# If the value starts with 4 or 9 use the subtractive form representing one symbol subtracted from the following symbol, for example, 4 is 1 (I) less than 5 (V): IV and 9 is 1 (I) less than 10 (X): IX. Only the following subtractive forms are used: 4 (IV), 9 (IX), 40 (XL), 90 (XC), 400 (CD) and 900 (CM).
# Only powers of 10 (I, X, C, M) can be appended consecutively at most 3 times to represent multiples of 10. You cannot append 5 (V), 50 (L), or 500 (D) multiple times. If you need to append a symbol 4 times use the subtractive form.
# Given an integer, convert it to a Roman numeral.
#
# Example 1:
# Input: num = 3749
# Output: "MMMDCCXLIX"
# Explanation:
# 3000 = MMM as 1000 (M) + 1000 (M) + 1000 (M)
#  700 = DCC as 500 (D) + 100 (C) + 100 (C)
#   40 = XL as 10 (X) less of 50 (L)
#    9 = IX as 1 (I) less of 10 (X)
# Note: 49 is not 1 (I) less of 50 (L) because the conversion is based on decimal places
#
# Example 2:
# Input: num = 58
# Output: "LVIII"
# Explanation:
# 50 = L
#  8 = VIII
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The provided function `int_to_roman(num)` seems to correctly implement the logic to convert an integer into a Roman numeral, following the standard rules mentioned. The function uses a list of tuples, `val_symbols`, which maps integer values to their corresponding Roman numerals. It iterates through this list and subtracts the greatest possible value from the input while appending the corresponding symbol to the result until the entire number is converted.
#
# The docstring follows Google style documentation guidelines: it clearly describes the function's purpose, parameters, return type, and includes an example of how to use the function correctly.
#
# There are no apparent syntax errors in the code. The logic for handling both standard additions and subtractive forms (IV, IX, XL, XC, CD, CM) is implemented as described in the problem statement rules.
#
# Based on the review, there's no modification needed in the provided implementation as it correctly matches the original query requirements and adheres to best practices for Python code readability and documentation.
#
# [[ ## answer ## ]]
# ```python
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
# ```
#
# [[ ## completed ## ]]
#
#
#
#
#
# agent state: reflection agent:idle
# --------------------------------------------------
# user
# Seven different symbols represent Roman numerals with the following values:
#
# Symbol	Value
# I	1
# V	5
# X	10
# L	50
# C	100
# D	500
# M	1000
# Roman numerals are formed by appending the conversions of decimal place values from highest to lowest. Converting a decimal place value into a Roman numeral has the following rules:
#
# If the value does not start with 4 or 9, select the symbol of the maximal value that can be subtracted from the input, append that symbol to the result, subtract its value, and convert the remainder to a Roman numeral.
# If the value starts with 4 or 9 use the subtractive form representing one symbol subtracted from the following symbol, for example, 4 is 1 (I) less than 5 (V): IV and 9 is 1 (I) less than 10 (X): IX. Only the following subtractive forms are used: 4 (IV), 9 (IX), 40 (XL), 90 (XC), 400 (CD) and 900 (CM).
# Only powers of 10 (I, X, C, M) can be appended consecutively at most 3 times to represent multiples of 10. You cannot append 5 (V), 50 (L), or 500 (D) multiple times. If you need to append a symbol 4 times use the subtractive form.
# Given an integer, convert it to a Roman numeral.
#
# Example 1:
# Input: num = 3749
# Output: "MMMDCCXLIX"
# Explanation:
# 3000 = MMM as 1000 (M) + 1000 (M) + 1000 (M)
#  700 = DCC as 500 (D) + 100 (C) + 100 (C)
#   40 = XL as 10 (X) less of 50 (L)
#    9 = IX as 1 (I) less of 10 (X)
# Note: 49 is not 1 (I) less of 50 (L) because the conversion is based on decimal places
#
# Example 2:
# Input: num = 58
# Output: "LVIII"
# Explanation:
# 50 = L
#  8 = VIII
# --------------------------------------------------
# --------------------------------------------------
# reflection agent
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
# --------------------------------------------------
# --------------------------------------------------
# reflection agent
# ```python
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
# ```
# --------------------------------------------------

# %%
dspy.inspect_history(n=10)
# Out:
# [2025-12-10T10:50:24.609667]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `context` (str):
# 3. `question` (str):
# 4. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `context`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# /no_think You are a helpful coding assistant.
# You task is to write a python function and return the implementation of the function.
# Some requirements:
# - The logic is clear and easy to understand.
# - The function arguments and return values (if any) should be typed.
# - If the function is too long (for example greater than 80 lines), split the logic into multiple smaller functions.
# - All functions should have docstring explanation. In the explanation, there should be an simple example to illustrate the function and how to call it.
# - The response should contain function with docstring explanation. And DO NOT contain explanation outside of the code
#
#
# [[ ## context ## ]]
#
#
# [[ ## question ## ]]
# Seven different symbols represent Roman numerals with the following values:
#
# Symbol	Value
# I	1
# V	5
# X	10
# L	50
# C	100
# D	500
# M	1000
# Roman numerals are formed by appending the conversions of decimal place values from highest to lowest. Converting a decimal place value into a Roman numeral has the following rules:
#
# If the value does not start with 4 or 9, select the symbol of the maximal value that can be subtracted from the input, append that symbol to the result, subtract its value, and convert the remainder to a Roman numeral.
# If the value starts with 4 or 9 use the subtractive form representing one symbol subtracted from the following symbol, for example, 4 is 1 (I) less than 5 (V): IV and 9 is 1 (I) less than 10 (X): IX. Only the following subtractive forms are used: 4 (IV), 9 (IX), 40 (XL), 90 (XC), 400 (CD) and 900 (CM).
# Only powers of 10 (I, X, C, M) can be appended consecutively at most 3 times to represent multiples of 10. You cannot append 5 (V), 50 (L), or 500 (D) multiple times. If you need to append a symbol 4 times use the subtractive form.
# Given an integer, convert it to a Roman numeral.
#
# Example 1:
# Input: num = 3749
# Output: "MMMDCCXLIX"
# Explanation:
# 3000 = MMM as 1000 (M) + 1000 (M) + 1000 (M)
#  700 = DCC as 500 (D) + 100 (C) + 100 (C)
#   40 = XL as 10 (X) less of 50 (L)
#    9 = IX as 1 (I) less of 10 (X)
# Note: 49 is not 1 (I) less of 50 (L) because the conversion is based on decimal places
#
# Example 2:
# Input: num = 58
# Output: "LVIII"
# Explanation:
# 50 = L
#  8 = VIII
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# Okay, so I need to write a Python function that converts an integer to a Roman numeral. Let me think about how to approach this.
#
# First, the problem says there are seven symbols with specific values. The rules involve subtractive forms like IV for 4, IX for 9, etc. The key is to handle the subtractive cases and then build the Roman numeral from highest to lowest.
#
# I remember that Roman numerals are constructed by subtracting certain values when the next higher value is needed. For example, 4 is IV (5 - 1), 9 is IX (10 - 1), 40 is XL (50 - 10), etc.
#
# The standard approach for this problem is to have a list of tuples that map integer values to their corresponding Roman numeral strings, ordered from largest to smallest. Then, iterate through this list, subtracting the largest possible value from the number each time, and appending the corresponding symbol to the result.
#
# Wait, but the problem mentions that only certain subtractive forms are allowed. So the list should include the subtractive pairs as well. For example, for 400, it's CD (500 - 100), so the list should have entries like (1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'), etc.
#
# Let me list out the possible values in descending order. The standard values are:
#
# 1000: M
# 900: CM
# 500: D
# 400: CD
# 100: C
# 90: XC
# 50: L
# 40: XL
# 10: X
# 9: IX
# 5: V
# 4: IV
# 1: I
#
# So the order of the list should be from highest to lowest: 1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1.
#
# Wait, but the problem says that only certain subtractive forms are used, so the list should include the subtractive combinations as single entries. For example, 900 is represented as 'CM', so in the list, the entry for 900 is 'CM'.
#
# So the code would iterate through this list, and for each value, subtract it from the input number as many times as possible, appending the corresponding symbol.
#
# Wait, but the problem says that the function should return the Roman numeral as a string.
#
# Let me think: For example, if the input is 3749, the function should return "MMMDCCXLIX".
#
# So, the approach is:
#
# 1. Create a list of tuples where each tuple is (integer value, corresponding Roman numeral string), ordered from highest to lowest.
#
# 2. Initialize an empty string for the result.
#
# 3. For each value in the list:
#    a. While the current number is greater than or equal to the value:
#       i. Append the Roman numeral string to the result.
#       ii. Subtract the value from the number.
#
# Wait, but the problem states that the subtractive forms are only for 4 and 9 in the decimal places. So the list should be ordered such that the subtractive pairs are included as single entries. For example, 900 is 'CM', so when the number is 900, we add 'CM' once.
#
# So the list would be:
#
# [
#     (1000, 'M'),
#     (900, 'CM'),
#     (500, 'D'),
#     (400, 'CD'),
#     (100, 'C'),
#     (90, 'XC'),
#     (50, 'L'),
#     (40, 'XL'),
#     (10, 'X'),
#     (9, 'IX'),
#     (5, 'V'),
#     (4, 'IV'),
#     (1, 'I')
# ]
#
# Yes, this list covers all the possible cases. Now, the algorithm would be:
#
# For the given integer num, iterate through this list. For each value in the list:
#
# - While num >= value:
#    - Add the corresponding symbol to the result
#    - Subtract value from num
#
# This way, for example, 4 would be handled by the 'IV' entry, since 4 >= 4, so add 'IV' once, then num becomes 0.
#
# Let me test this with example 2: num = 58.
#
# The list starts with 1000, which is larger than 58, so skip. Then 900, 500, 400, 100, 90 (90 is larger than 58? No, 90 is 90, which is larger than 58. Wait, no: 90 is 90, so 58 is less than 90. So the next is 50: 50 is in the list. 58 >=50: add 'L', subtract 50, remaining 8.
#
# Then next is 40: 8 <40, skip. Then 10: 8 <10, skip. Then 9: 8 <9, skip. Then 5: 8 >=5: add 'V', subtract 5, remaining 3. Then 4: 3 <4, skip. Then 1: 3 >=1: add 'I' three times. So result is 'L' + 'V' + 'III' = 'LVIII' which is correct.
#
# Yes, this approach seems to work.
#
# So the function would be:
#
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# Wait, but the problem says that the function should have a docstring with an example. Let me check the example.
#
# In the example, for 58, the output is 'LVIII', which matches.
#
# Another test: num=3749.
#
# Let's see:
#
# 3749 divided by 1000: 3 times, so MMM (3000).
#
# 3749-3000 = 749.
#
# 749: next is 500 (D) → 749 >=500 → D, now 249.
#
# 249: next 100 (C) → 249 >=100 → C, 149.
#
# 149: next 100 → C, now 49.
#
# 49: 40 (XL) → 49 >=40 → XL, 9.
#
# 9: IX → I and X? Wait, 9 is 'IX', so append 'IX' once.
#
# So result is MMM + DCC (200) → DCC is 500 + 100 + 100 → 700? Wait, 3000 + 700 = 3700, then 40 and 9 → 49. So 3749 → MMM D CC XL IX → MMMDCCXLIX.
#
# Yes, which matches the example.
#
# So the code should work.
#
# The function is under 80 lines, so no need to split into smaller functions. The docstring has an example.
#
# Let me check the requirements again:
#
# - The logic is clear and easy to understand: yes, the code uses a list of tuples and iterates through them.
#
# - Arguments and return values typed: yes, num is int, returns str.
#
# - Not too long: this code is short.
#
# - Docstring with example: yes.
#
# So the answer should be this function.
#
# Wait, the problem says "DO NOT contain explanation outside of the code". So the response should only have the code with the docstring, no extra text.
#
# So the answer field should be the code block.
#
# Wait, the user's instruction says: "The response should contain function with docstring explanation. And DO NOT contain explanation outside of the code".
#
# So the answer is the code.
#
# So the output should be:
#
# [[ ## reasoning ## ]]
# The function uses a list of tuples (integer values and corresponding Roman symbols) ordered from highest to lowest. It iterates through this list, appending the symbol to the result each time the current number is greater than or equal to the value, then subtracts the value from the number. This handles subtractive cases like IV (4) and IX (9) by including them as single entries in the list. The algorithm ensures the correct conversion by processing the highest possible values first.
#
# [[ ## answer ## ]]
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# [[ ## completed ## ]]
#
# Wait, but the problem says that the function should be written with the docstring. The example uses a triple-slash comment, but in Python, the docstring is a triple quote.
#
# Wait, the code I wrote has a docstring starting with triple quotes. Wait, no: in the code above, the docstring is written with a triple quote. Let me check.
#
# In the code as written:
#
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [ ... ]
#
# Yes, the docstring uses triple quotes. Wait, no: in Python, the docstring starts with triple quotes. Wait, but in the code I wrote, it's using triple quotes.
#
# Wait, no: the user's example uses a triple-quoted string. Wait, the code I wrote has a docstring that's a triple-quoted string.
#
# Wait, no: in the code above, the docstring is written with triple quotes. Let me check.
#
# In Python, a docstring is written as:
#
# '''...'''
#
# But in the code I wrote, the docstring starts with a triple quote. Wait, no. The code I wrote has:
#
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#
# This is a multiline docstring without triple quotes. Wait, no: in Python, the standard way is to use triple quotes for multi-line docstrings. But in the code, the user's example shows that the docstring can be written with triple quotes.
#
# Wait, the problem says: "All functions should have docstring explanation. In the explanation, there should be an simple example to illustrate the function and how to call it."
#
# In the code, the docstring is written with triple quotes. Let me adjust the code to use triple quotes.
#
# Wait, in Python, the correct way to write a multi-line docstring is with triple quotes. So the code should be:
#
# def int_to_roman(num):
#     """
#     Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# Yes, this uses triple quotes for the docstring. So the code is correct.
#
# So the answer field should be this code.
#
# Let me check the example. The function returns 'LVIII' for 58, which matches.
#
# Yes. So the code should be correct.
#
# Therefore, the reasoning is as above, and the answer is the code.
# </think>
#
# [[ ## reasoning ## ]]
# The function uses a list of tuples (integer values and corresponding Roman symbols) ordered from highest to lowest. It iterates through this list, appending the symbol to the result each time the current number is greater than or equal to the value, then subtracts the value from the number. This handles subtractive cases like IV (4) and IX (9) by including them as single entries in the list. The algorithm ensures correct conversion by processing the highest possible values first.
#
# [[ ## answer ## ]]
# def int_to_roman(num):
#     """
#     Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T10:50:55.436357]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `context` (str):
# 3. `question` (str):
# 4. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `context`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# /no_think You are a excellent code reviewer and refactor.
# Given a function implementation and it explanation in the context field, your task is to review the code and correct if contains any mistake.
# Some note:
# - For the implementation, check if the orignal query and suggested implementation are match.
# - Is there any syntax error in the code.
# - For the explanation, verify if the docstring follows Google style docstring.
# - In the docstring, make sure to have an example to call the function.
# - Make sure the final output only contain code, inline code comment and docstring, nothing else.
# - If no modificatoin is made, just return the original implementation
#
# [[ ## context ## ]]
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
#
# [[ ## question ## ]]
# Seven different symbols represent Roman numerals with the following values:
#
# Symbol	Value
# I	1
# V	5
# X	10
# L	50
# C	100
# D	500
# M	1000
# Roman numerals are formed by appending the conversions of decimal place values from highest to lowest. Converting a decimal place value into a Roman numeral has the following rules:
#
# If the value does not start with 4 or 9, select the symbol of the maximal value that can be subtracted from the input, append that symbol to the result, subtract its value, and convert the remainder to a Roman numeral.
# If the value starts with 4 or 9 use the subtractive form representing one symbol subtracted from the following symbol, for example, 4 is 1 (I) less than 5 (V): IV and 9 is 1 (I) less than 10 (X): IX. Only the following subtractive forms are used: 4 (IV), 9 (IX), 40 (XL), 90 (XC), 400 (CD) and 900 (CM).
# Only powers of 10 (I, X, C, M) can be appended consecutively at most 3 times to represent multiples of 10. You cannot append 5 (V), 50 (L), or 500 (D) multiple times. If you need to append a symbol 4 times use the subtractive form.
# Given an integer, convert it to a Roman numeral.
#
# Example 1:
# Input: num = 3749
# Output: "MMMDCCXLIX"
# Explanation:
# 3000 = MMM as 1000 (M) + 1000 (M) + 1000 (M)
#  700 = DCC as 500 (D) + 100 (C) + 100 (C)
#   40 = XL as 10 (X) less of 50 (L)
#    9 = IX as 1 (I) less of 10 (X)
# Note: 49 is not 1 (I) less of 50 (L) because the conversion is based on decimal places
#
# Example 2:
# Input: num = 58
# Output: "LVIII"
# Explanation:
# 50 = L
#  8 = VIII
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The provided function `int_to_roman(num)` seems to correctly implement the logic to convert an integer into a Roman numeral, following the standard rules mentioned. The function uses a list of tuples, `val_symbols`, which maps integer values to their corresponding Roman numerals. It iterates through this list and subtracts the greatest possible value from the input while appending the corresponding symbol to the result until the entire number is converted.
#
# The docstring follows Google style documentation guidelines: it clearly describes the function's purpose, parameters, return type, and includes an example of how to use the function correctly.
#
# There are no apparent syntax errors in the code. The logic for handling both standard additions and subtractive forms (IV, IX, XL, XC, CD, CM) is implemented as described in the problem statement rules.
#
# Based on the review, there's no modification needed in the provided implementation as it correctly matches the original query requirements and adheres to best practices for Python code readability and documentation.
#
# [[ ## answer ## ]]
# ```python
# def int_to_roman(num):
#     """Convert an integer to a Roman numeral.
#
#     Args:
#         num (int): The integer to convert.
#
#     Returns:
#         str: The Roman numeral representation.
#
#     Example:
#         >>> int_to_roman(58)
#         'LVIII'
#     """
#     val_symbols = [
#         (1000, 'M'),
#         (900, 'CM'),
#         (500, 'D'),
#         (400, 'CD'),
#         (100, 'C'),
#         (90, 'XC'),
#         (50, 'L'),
#         (40, 'XL'),
#         (10, 'X'),
#         (9, 'IX'),
#         (5, 'V'),
#         (4, 'IV'),
#         (1, 'I')
#     ]
#     result = []
#     for value, symbol in val_symbols:
#         while num >= value:
#             result.append(symbol)
#             num -= value
#     return ''.join(result)
# ```
#
# [[ ## completed ## ]]

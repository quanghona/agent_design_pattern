# %% [markdown]
# # Simple loop agent
#
# In this example, we will create an loop agent that simply generate a description base on a same query and get all results
#
# In other word, this is a "for loop" agent.

# %%
from collections.abc import Sequence
from typing import List

from a2a.types import AgentCapabilities, AgentCard, AgentSkill
from aap_core.agent import BaseAgent
from aap_core.chain import BaseLLMChain
from aap_core.orchestration import LoopAgent
from aap_core.types import AgentMessage, AgentResponse
from aap_dspy.chain import BaseSignatureAdapter, ChatCausalMultiTurnsChain

import dspy

# %%
class QA(dspy.Signature):
    guide: str = dspy.InputField(optional=True)
    question: str = dspy.InputField()
    answer: str = dspy.OutputField()
    history: dspy.History = dspy.InputField()


class SignatureAdapter(BaseSignatureAdapter[QA]):
    def msg2sig(self, message: AgentMessage) -> List[QA]:
        history = dspy.History(messages=[])
        q, a = None, None
        for response in message.responses:
            if response[0] == "user":
                q = response[1]
            elif response[0] == "tool":
                pass
            elif response[0] == "system":
                pass
            else:
                a = response[1]

            if q is not None and a is not None:
                history.messages.append({"question": q, "answer": a})
                q, a = None, None

        guide_str = self._prefill_dict.get("guide", "")
        qa = QA(question=message.query, answer="", history=history, guide=guide_str)
        return [qa]

    def sig2msg(self, signatures: List[QA], name: str) -> List[AgentResponse]:
        responses = []
        for signature in signatures:
            responses.append(("user", signature.question))
            responses.append((name, signature.answer))
        return responses

# %%
class Agent(BaseAgent):
    chain: BaseLLMChain

    def execute(self, message: AgentMessage, **kwargs) -> AgentMessage:
        self.state = "running"
        message = self.chain.invoke(message, **kwargs)
        message.execution_result = "success"
        message.origin = self.card.name
        self.state = "idle"
        return message

# %%
from collections.abc import Generator

system_prompt = """You are a genius and creative writer."""

max_iteration = 5

def state_callback(state: str):
    print(f"agent state: {state}")

def iter(max_iteration: int) -> Generator[bool, None, None]:
    n = 0
    while True:
        yield n >= max_iteration
        n = (n + 1) % (max_iteration + 1)

model = dspy.LM(model="ollama_chat/llama3.2:latest", api_base="http://192.168.55.1:11434", api_key="", temperature=1.5, cache=False)
adapter = SignatureAdapter.with_prefill({"guide": system_prompt})
predictor = dspy.ChainOfThought(QA)
chain = ChatCausalMultiTurnsChain(QA, predictor=predictor, adapter=adapter).with_lm(model)
writer_skill = AgentSkill(
    id='writer-skill',
    name="writer skill",
    description="writer skill",
    tags=['writer']
)
writer_card = AgentCard(
    name="writer agent",
    description="Writer agent",
    skills=[writer_skill],
    capabilities=AgentCapabilities(),
    default_input_modes=['text'],
    default_output_modes=['text'],
    url="localhost",
    version="0.1.0"
)
loop_skill = AgentSkill(
    id='loop-skill',
    name="loop skill",
    description="loop skill",
    tags=['loop']
)
loop_card = AgentCard(
    name="loop agent",
    description="loop agent",
    skills=[loop_skill],
    capabilities=AgentCapabilities(),
    default_input_modes=['text'],
    default_output_modes=['text'],
    url="localhost",
    version="0.1.0"
)
agent = Agent(chain=chain, card=writer_card, state_change_callback=state_callback)
loop_agent = LoopAgent(agent=agent, is_stop=iter(max_iteration), card=loop_card, state_change_callback=state_callback)

# %%
query = "Write a short poem with Shakespere's style about the peace before the storm."
message = loop_agent.execute(AgentMessage(query=query), keep_result=-1)

print(message)
print(f"message responses len: {len(message.responses)}")

for agent_name, response in message.responses:
    print(f"{agent_name}: {response}")
    print("-" * 50)
    print()
# Out:
# agent state: loop agent:running/writer agent:idle
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#0/writer agent:running
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#1/writer agent:running
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#2/writer agent:running
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#3/writer agent:running
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:running#4/writer agent:running
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:idle/writer agent:idle
# query="Write a short poem with Shakespere's style about the peace before the storm." query_media=None origin='loop agent' responses=[('writer agent', "O, fairest stillness, soft as summer's rain,\nThat sootheth troubled minds with gentle balm again.\nThy peace, like morning dew upon the grass,\nInvigorates the senses and refreshes the past."), ('writer agent', "When fair peace doth reign, a gentle guest,\nThe heart, in quiet, finds its nest;\nBut soon, alas, the winds do shift,\nAnd discord's storms begin to drift.\nYet still, 'tis beauty to behold\nThis fleeting calm, before the gale doth unfold."), ('writer agent', "O, fleeting calm that doth precede\nThe tempest's fury, how thou art divine,\nA gentle zephyr that doth softly breathe\nUpon my skin, a soothing balm of peace.\nAs darkness gathers on the distant horizon,\nI find solace in this tranquil hour,\nLest wild winds shake the foundations deep\nOf my soul, and stormy seas my spirit devour.\n\nAnd thus I'll savor each passing moment dear,\nFor time is short, and fate doth hasten near;\nYet in this fleeting calm, I'll find reprieve,\nAnd let the tempest's roar become my heartbeat's leave.\nO, peace before the storm, how precious art thou!"), ('writer agent', 'A gentle lullaby to those who wait,'), ('writer agent', "O, fairest calm that doth precede the tempest's roar,\nA period of repose, wherein peaceful silence holds court once more.\nYet, even as thou dost thy tranquil vigil keep,\nBeware, dear heart, for signs of turmoil oft in slumber creep.\n\nThe gentle breeze that stirs not a leafy tree\nMay hide within its soothing sighs the warning wild and free;\nThe bright blue sky, though cloudless to the naked eye,\nConceals within it storms that brew beneath the surface, ready to deny\n\nAll peace and calm, and in their stead bestow\nA fury fierce, with rains of wrath and darkness laid low.\nSo heed this counsel well, dear heart, and beware the signs,\nLest when the tempest rages on, thou art unprepared for its shrill, discordant whines.")] context=None execution_result=None error_message=None media=None
# message responses len: 5
# writer agent: O, fairest stillness, soft as summer's rain,
# That sootheth troubled minds with gentle balm again.
# Thy peace, like morning dew upon the grass,
# Invigorates the senses and refreshes the past.
# --------------------------------------------------
#
# writer agent: When fair peace doth reign, a gentle guest,
# The heart, in quiet, finds its nest;
# But soon, alas, the winds do shift,
# And discord's storms begin to drift.
# Yet still, 'tis beauty to behold
# This fleeting calm, before the gale doth unfold.
# --------------------------------------------------
#
# writer agent: O, fleeting calm that doth precede
# The tempest's fury, how thou art divine,
# A gentle zephyr that doth softly breathe
# Upon my skin, a soothing balm of peace.
# As darkness gathers on the distant horizon,
# I find solace in this tranquil hour,
# Lest wild winds shake the foundations deep
# Of my soul, and stormy seas my spirit devour.
#
# And thus I'll savor each passing moment dear,
# For time is short, and fate doth hasten near;
# Yet in this fleeting calm, I'll find reprieve,
# And let the tempest's roar become my heartbeat's leave.
# O, peace before the storm, how precious art thou!
# --------------------------------------------------
#
# writer agent: A gentle lullaby to those who wait,
# --------------------------------------------------
#
# writer agent: O, fairest calm that doth precede the tempest's roar,
# A period of repose, wherein peaceful silence holds court once more.
# Yet, even as thou dost thy tranquil vigil keep,
# Beware, dear heart, for signs of turmoil oft in slumber creep.
#
# The gentle breeze that stirs not a leafy tree
# May hide within its soothing sighs the warning wild and free;
# The bright blue sky, though cloudless to the naked eye,
# Conceals within it storms that brew beneath the surface, ready to deny
#
# All peace and calm, and in their stead bestow
# A fury fierce, with rains of wrath and darkness laid low.
# So heed this counsel well, dear heart, and beware the signs,
# Lest when the tempest rages on, thou art unprepared for its shrill, discordant whines.
# --------------------------------------------------

# %%
query = "Write a poem with Shakespere's style about the peace before the storm."
message = loop_agent.execute(AgentMessage(query=query), keep_result=1)

print(message)
print(f"message responses len: {len(message.responses)}")

for agent_name, response in message.responses:
    print(f"{agent_name}: {response}")
    print("-" * 50)
    print()
# Out:
# agent state: loop agent:running/writer agent:idle
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#0/writer agent:running
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#1/writer agent:running
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#2/writer agent:running
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#3/writer agent:running
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:running#4/writer agent:running
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:idle/writer agent:idle
# query="Write a poem with Shakespere's style about the peace before the storm." query_media=None origin='loop agent' responses=[('writer agent', "O, fairest calm, thy peaceful reign doth bind\nThe world in sweet captivity of rest;\nAs if 'twere midsummer's warmest day,\nAnd all around, a soothing balm did nest.\n\nBut lo, how soon thy tranquil veil doth lift,\nTo unveil the tumultuous skies above;\nA storm awakes, with darkness and with grief,\nThat tempests wrath doth hide its secret love.\n\nYet in that fleeting moment 'twixt the calm\nAnd turbulent chaos, stands our peace of mind;\nAs when a sunset's warmth upon the farm\nGives way to stars, with heavenly whispers kind.\n\n'Tis here, dear heart, we find our greatest test,\nThe fragile dance 'twixt serenity and stormy unrest;\nWhen passions rage, as tempests wildly rest,\nWe must summon inner peace, and gently calm our form.")] context=None execution_result=None error_message=None media=None
# message responses len: 1
# writer agent: O, fairest calm, thy peaceful reign doth bind
# The world in sweet captivity of rest;
# As if 'twere midsummer's warmest day,
# And all around, a soothing balm did nest.
#
# But lo, how soon thy tranquil veil doth lift,
# To unveil the tumultuous skies above;
# A storm awakes, with darkness and with grief,
# That tempests wrath doth hide its secret love.
#
# Yet in that fleeting moment 'twixt the calm
# And turbulent chaos, stands our peace of mind;
# As when a sunset's warmth upon the farm
# Gives way to stars, with heavenly whispers kind.
#
# 'Tis here, dear heart, we find our greatest test,
# The fragile dance 'twixt serenity and stormy unrest;
# When passions rage, as tempests wildly rest,
# We must summon inner peace, and gently calm our form.
# --------------------------------------------------

# %%
query = "Write a poem with Shakespere's style about the peace before the storm."
message = loop_agent.execute(AgentMessage(query=query), keep_result=3)

print(message)
print(f"message responses len: {len(message.responses)}")

for agent_name, response in message.responses:
    print(f"{agent_name}: {response}")
    print("-" * 50)
    print()
# Out:
# agent state: loop agent:running/writer agent:idle
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#0/writer agent:running
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#1/writer agent:running
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#2/writer agent:running
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#3/writer agent:running
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:running#4/writer agent:running
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:idle/writer agent:idle
# query="Write a poem with Shakespere's style about the peace before the storm." query_media=None origin='loop agent' responses=[('writer agent', "O, wouldst thou learn to discern the signs of woe\nThat peace doth hide, and storms of turmoil sow?\nHeed Nature's warning, whispering through the trees,\nAnd when 'tis quiet, gather courage to seize\n\nThe hour of action, ere the storm doth break\nAnd with a steadfast heart, thy path unmake.\nFor though in calm, we may be led astray,\nIn chaos, wisdom finds its just array."), ('writer agent', '{\'Sonnet of Tranquility\': ["When calm descendeth, as \'tis now doth lie", \'Before the tempests fierce and wild assailed\', "My heart, in silence, with no sorrow\'s sigh", "Like still waters\' quietness is my tale"], \'Continuation of Sonnet\': [\'Yet in this calm, my soul doth feel a might\']}'), ('writer agent', "O, wouldst thou calm this troubled breast,\nAs 'fore the storm, when skies are blest?\nWhen sunbeams fade, and clouds draw near,\nAnd night's dark veil doth gently appear.")] context=None execution_result=None error_message=None media=None
# message responses len: 3
# writer agent: O, wouldst thou learn to discern the signs of woe
# That peace doth hide, and storms of turmoil sow?
# Heed Nature's warning, whispering through the trees,
# And when 'tis quiet, gather courage to seize
#
# The hour of action, ere the storm doth break
# And with a steadfast heart, thy path unmake.
# For though in calm, we may be led astray,
# In chaos, wisdom finds its just array.
# --------------------------------------------------
#
# writer agent: {'Sonnet of Tranquility': ["When calm descendeth, as 'tis now doth lie", 'Before the tempests fierce and wild assailed', "My heart, in silence, with no sorrow's sigh", "Like still waters' quietness is my tale"], 'Continuation of Sonnet': ['Yet in this calm, my soul doth feel a might']}
# --------------------------------------------------
#
# writer agent: O, wouldst thou calm this troubled breast,
# As 'fore the storm, when skies are blest?
# When sunbeams fade, and clouds draw near,
# And night's dark veil doth gently appear.
# --------------------------------------------------

# %%
def custom_keep_logic(responses: Sequence[AgentResponse]) -> List[AgentResponse]:
    return list(responses)


query = "Write a poem with Shakespere's style about the peace before the storm."
message = loop_agent.execute(AgentMessage(query=query), keep_result=custom_keep_logic)

print(message)
print(f"message responses len: {len(message.responses)}")

for agent_name, response in message.responses:
    print(f"{agent_name}: {response}")
    print("-" * 50)
    print()
# Out:
# agent state: loop agent:running/writer agent:idle
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#0/writer agent:running
# agent state: loop agent:running#0/writer agent:idle
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#1/writer agent:running
# agent state: loop agent:running#1/writer agent:idle
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#2/writer agent:running
# agent state: loop agent:running#2/writer agent:idle
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#3/writer agent:running
# agent state: loop agent:running#3/writer agent:idle
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:running#4/writer agent:running
# agent state: loop agent:running#4/writer agent:idle
# agent state: loop agent:idle/writer agent:idle
# query="Write a poem with Shakespere's style about the peace before the storm." query_media=None origin='loop agent' responses=[('writer agent', 'Shall I Compare Thee to a Stormy Night?'), ('writer agent', "Before the tempest's darkest hour descends,\nWhen skies are grey and winds do fiercely trend,\nThere lies a peaceful calm, serene and still,\nA fleeting moment 'gainst life's raging will.\n\n'Tis like the eve of night, when starlight gleams,\nAnd in the darkness, mortal cares esteem\nTheir fleeting breath, as winds prepare to roar,\nAnd seas to swell, on yonder distant shore.\n\nThis pause before the stormy tumult's sound,\nA time for introspection, where hearts are found,\nIn quiet contemplation, or in sweet delight,\nWe find our strength, in darkness' dismal night."), ('writer agent', "O, when that tempest rages at its might,\nAnd world, aflame with wrath, doth suffer dire,\n'Tis then we found our souls were not in flight;\nThe peace before was only prelude's fire."), ('writer agent', "O, fair tranquility, thou softly doth descend\nLike gentle summer showers upon parched earth's end.\nA soothing calm, 'twixt day and night's dark shade,\nThat whispers warnings of an approaching gale.\n\nThy lullabying waves, a fleeting stillness hold\nAgainst the tempest's gathering stormy fold.\nThe air is heavy with unspoken fate's decree\nAs in thy quiet heart, peace lies, unseen by me.\n\nThen listen well to nature's ominous tone,\nThat whispers of an ending peace is not to be known.\nBut as long as serenity doth reign and sleep\nFinds rest awhile from turmoil's waves that creep,"), ('writer agent', "O, peace that precedes the stormy night!\nHow gently you enfolds the troubled sight!\nA respite from rage and tumult dire,\nLuring the weary soul to secret fire.\n\nYet, 'tis in fleeting calm we're oft betrayed,\nAs turbulent despair does turmoil display.\nFor when tranquility doth wear a mask,\nThe tempest rages on, leaving naught but darkened track.")] context=None execution_result=None error_message=None media=None
# message responses len: 5
# writer agent: Shall I Compare Thee to a Stormy Night?
# --------------------------------------------------
#
# writer agent: Before the tempest's darkest hour descends,
# When skies are grey and winds do fiercely trend,
# There lies a peaceful calm, serene and still,
# A fleeting moment 'gainst life's raging will.
#
# 'Tis like the eve of night, when starlight gleams,
# And in the darkness, mortal cares esteem
# Their fleeting breath, as winds prepare to roar,
# And seas to swell, on yonder distant shore.
#
# This pause before the stormy tumult's sound,
# A time for introspection, where hearts are found,
# In quiet contemplation, or in sweet delight,
# We find our strength, in darkness' dismal night.
# --------------------------------------------------
#
# writer agent: O, when that tempest rages at its might,
# And world, aflame with wrath, doth suffer dire,
# 'Tis then we found our souls were not in flight;
# The peace before was only prelude's fire.
# --------------------------------------------------
#
# writer agent: O, fair tranquility, thou softly doth descend
# Like gentle summer showers upon parched earth's end.
# A soothing calm, 'twixt day and night's dark shade,
# That whispers warnings of an approaching gale.
#
# Thy lullabying waves, a fleeting stillness hold
# Against the tempest's gathering stormy fold.
# The air is heavy with unspoken fate's decree
# As in thy quiet heart, peace lies, unseen by me.
#
# Then listen well to nature's ominous tone,
# That whispers of an ending peace is not to be known.
# But as long as serenity doth reign and sleep
# Finds rest awhile from turmoil's waves that creep,
# --------------------------------------------------
#
# writer agent: O, peace that precedes the stormy night!
# How gently you enfolds the troubled sight!
# A respite from rage and tumult dire,
# Luring the weary soul to secret fire.
#
# Yet, 'tis in fleeting calm we're oft betrayed,
# As turbulent despair does turmoil display.
# For when tranquility doth wear a mask,
# The tempest rages on, leaving naught but darkened track.
# --------------------------------------------------

# %%
dspy.inspect_history(n=10)
# Out:
# [2025-12-10T12:26:09.166806]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# To craft a poem of peace before the storm,
# I must consider the calm's gentle form.
# 'Tis in this tranquil hour, I find my muse,
# That whispers truths, and gentle hopes imbues.
#
# [[ ## answer ## ]]
# O, fairest stillness, thou dost softly fall,
# As twilight veils the world in hush'd recall.
# The winds, like zephyrs, whisper secrets low,
# And clouds, aflame with sunset's warmest glow.
# Thy somber peace, a tranquil sea, doth lay
# Before the tempest's mighty, darkened day.
# And in thine eye-like stillness, I behold
# A fleeting glimpse of tranquility to hold.
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T12:26:16.180151]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Before the tempest's fierce and furious sway,
# When calmest skies do veil the turbulent day,
# And gentle zephyrs whisper through the trees,
# As if to warn of dangers that increase,
#
# 'Tis peace that reigns, a fleeting, fancied bliss,
# That lures us to forget life's bitter miss,
# Yet in this tranquility, we often stray
# From wisdom's counsel and the path to sway.
#
# But heed not whispers that deceitful peace doth bring;
# For hidden beneath its serene, still ring,
# A storm awakens, with fury unbound,
# To shatter calm and leave destruction all around.
#
# [[ ## answer ## ]]
# O, wouldst thou learn to discern the signs of woe
# That peace doth hide, and storms of turmoil sow?
# Heed Nature's warning, whispering through the trees,
# And when 'tis quiet, gather courage to seize
#
# The hour of action, ere the storm doth break
# And with a steadfast heart, thy path unmake.
# For though in calm, we may be led astray,
# In chaos, wisdom finds its just array.
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T12:26:23.093424]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The task demands a poetic composition, reminiscent of Shakespeare's works,
# with themes of peace before the tempest's rise. To write effectively,
# one must employ iambic pentameter and rich metaphors.
#
# [[ ## answer ## ])
# O, fleeting calm, that dost descend upon
# the world, like evening's gentle hush,
# as sunset's warmth doth slowly fade to dark,
# and with it, night's soft whispers to our rush.
# Yet in this peaceful twilight, we do stray,
# in verdant valleys where the wildflowers sway,
# beside crystal streams, whose silver light
# illuminates the quiet of the night.
#
# Forsooth, 'tis here, amidst this calm reprieve,
# that we must recognize the turmoil that doth seek
# its entry point, like an unforgotten grief,
# where passions simmered and unrest did seek
# to break forth. Thus in silence let us place
# our watchful eyes upon the stormy face
# of Nature, and await with anxious heart
# when calm shall yield to chaos, and the tempests' start.
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T12:26:29.475228]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# Inputs will have the following structure:
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# Outputs will be a JSON object with the following fields.
#
# {
#   "reasoning": "{reasoning}",
#   "answer": "{answer}"
# }
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with a JSON object in the following order of fields: `reasoning`, then `answer`.
#
#
# Response:
#
# {
#   "reasoning": "To craft a poem in Shakespeare's style, I will draw upon his classical structure and vocabulary. The poem's theme, 'peace before the storm,' allows for exploration of contrasts between serenity and turmoil.",
#   "answer": {
#     "Sonnet of Tranquility": [
#       "When calm descendeth, as 'tis now doth lie",
#       "Before the tempests fierce and wild assailed",
#       "My heart, in silence, with no sorrow's sigh",
#       "Like still waters' quietness is my tale"
#
#     ],
#     "Continuation of Sonnet": [
#       "Yet in this calm, my soul doth feel a might"
#      			         			]
#          	 				               }
#
#
#
#
# 	                    	}
#
#
#
#
#
# [2025-12-10T12:26:35.437020]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Before the tempest's darkening wings unfold,
# A hush of calm doth gently take its hold.
# The sun, a fiery orb, doth slowly sink,
# And with it, all the world's tumultuous think.
#
# The trees, like sentinels of peace, stand tall,
# Their leaves, a soft susurrus, whispering all
# Of calmer days, and summer's gentle breeze,
# That brought no storm, nor troubled ease.
#
# But as the west doth wear its darkest hue,
# And clouds, like ravens, gather, anew,
# A sense of stillness doth begin to creep,
# A feeling that the winds of change do keep.
#
# [[ ## answer ## ]]
# O, wouldst thou calm this troubled breast,
# As 'fore the storm, when skies are blest?
# When sunbeams fade, and clouds draw near,
# And night's dark veil doth gently appear.
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T12:26:40.560676]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# In calmer realms, where darkness lies in wait,
# A fragile peace doth reign, a temporary state.
# 'Tis but a truce 'twixt turmoil's raging sea
# And stormy night, that brings tempests to be.
#
# The wind doth whisper secrets, soft and low,
# Of trials past, of conquests yet to know;
# And though the eye of calm doth soothe the soul,
# A turbulent heart doth its unrest control.
#
# Yet still, in tranquil guise, it holds its ground,
# A moment's respite, 'fore nature's loud surround.
# The tempest rages, wild and free from pain,
# Yet peaceful hearts prepare for coming rain.
#
# [[ ## answer ## ]]
# Shall I Compare Thee to a Stormy Night?
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T12:26:48.699117]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Before the tempest's darkest hour descends,
# When skies are grey and winds do fiercely trend,
# There lies a peaceful calm, serene and still,
# A fleeting moment 'gainst life's raging will.
#
# 'Tis like the eve of night, when starlight gleams,
# And in the darkness, mortal cares esteem
# Their fleeting breath, as winds prepare to roar,
# And seas to swell, on yonder distant shore.
#
# This pause before the stormy tumult's sound,
# A time for introspection, where hearts are found,
# In quiet contemplation, or in sweet delight,
# We find our strength, in darkness' dismal night.
#
# [[ ## answer ## ]]
# Before the tempest's darkest hour descends,
# When skies are grey and winds do fiercely trend,
# There lies a peaceful calm, serene and still,
# A fleeting moment 'gainst life's raging will.
#
# 'Tis like the eve of night, when starlight gleams,
# And in the darkness, mortal cares esteem
# Their fleeting breath, as winds prepare to roar,
# And seas to swell, on yonder distant shore.
#
# This pause before the stormy tumult's sound,
# A time for introspection, where hearts are found,
# In quiet contemplation, or in sweet delight,
# We find our strength, in darkness' dismal night.
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T12:26:53.964406]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# In preparation for tempests' mighty roar,
# A moment's silence oft doth await
# Before the darkness, tumultuous score,
# When stormy wrath doth finally create.
#
# The calm before, a deceptive guise,
# Lulls souls to sleep, in ignorant bliss;
# Yet knowledge whispers secrets wise,
# That turbulence is not long-forspent bliss.
#
# Thus heed this lesson, hearts that would not stray
# From reason's counsel, warning voice most high:
# Prepare for chaos; know the coming day,
# When passions wild shall seize the midnight sky.
#
# [[ ## answer ## ]]
# O, when that tempest rages at its might,
# And world, aflame with wrath, doth suffer dire,
# 'Tis then we found our souls were not in flight;
# The peace before was only prelude's fire.
#
#  [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T12:27:00.436812]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The poem shall evoke a serene ambiance, foretelling the tempest's approach,
# With phrases echoing nature's whispers, an eerie calm to bestow.
# The stage is set, the curtain draws, revealing peace in stillness deep,
# Before the storm's awakening roar, a fleeting hush in quiet sleep.
#
# [[ ## answer ## ]]
# O, fair tranquility, thou softly doth descend
# Like gentle summer showers upon parched earth's end.
# A soothing calm, 'twixt day and night's dark shade,
# That whispers warnings of an approaching gale.
#
# Thy lullabying waves, a fleeting stillness hold
# Against the tempest's gathering stormy fold.
# The air is heavy with unspoken fate's decree
# As in thy quiet heart, peace lies, unseen by me.
#
# Then listen well to nature's ominous tone,
# That whispers of an ending peace is not to be known.
# But as long as serenity doth reign and sleep
# Finds rest awhile from turmoil's waves that creep,
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-12-10T12:27:06.089236]
#
# System message:
#
# Your input fields are:
# 1. `guide` (str):
# 2. `question` (str):
# 3. `history` (History):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## guide ## ]]
# {guide}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## history ## ]]
# {history}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `guide`, `question`, `history`, produce the fields `answer`.
#
#
# User message:
#
# [[ ## guide ## ]]
# You are a genius and creative writer.
#
# [[ ## question ## ]]
# Write a poem with Shakespere's style about the peace before the storm.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# In whispers of the wind, a calm descends,
# A soothing hush that all else transmutes.
# 'Tis in this fleeting pause before the ends
# Of nature's wrath, that peaceful hearts renew.
#
# The tempests' fury yet to be unveiled,
# Frets not the moments 'twixt serenity and gale.
# In tranquil intervals, like autumn leaves laid dry,
# Life's fragile balance waits for darkness to pass by.
#
# [[ ## answer ## ]]
# O, peace that precedes the stormy night!
# How gently you enfolds the troubled sight!
# A respite from rage and tumult dire,
# Luring the weary soul to secret fire.
#
# Yet, 'tis in fleeting calm we're oft betrayed,
# As turbulent despair does turmoil display.
# For when tranquility doth wear a mask,
# The tempest rages on, leaving naught but darkened track.
#
# [[ ## completed ## ]]
